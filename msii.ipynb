# %%
import pandas as pd

# %%
df = pd.read_csv("Salaries.csv")
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df.tail()
# Out:
#             Id   EmployeeName                    JobTitle  BasePay  \
# 148649  148650  Roy I Tillery                   Custodian      0.0
# 148650  148651   Not provided                Not provided      NaN
# 148651  148652   Not provided                Not provided      NaN
# 148652  148653   Not provided                Not provided      NaN
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148649          0.0      0.00       0.0      0.00              0.00  2014
# 148650          NaN       NaN       NaN      0.00              0.00  2014
# 148651          NaN       NaN       NaN      0.00              0.00  2014
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148649    NaN  San Francisco     NaN
# 148650    NaN  San Francisco     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
df["Year"].value_counts()
# Out:
# Year
# 2014    38123
# 2013    37606
# 2012    36766
# 2011    36159
# Name: count, dtype: int64

# %%
df[df["Year"]==2011]
# Out:
#           Id        EmployeeName  \
# 0          1      NATHANIEL FORD
# 1          2        GARY JIMENEZ
# 2          3      ALBERT PARDINI
# 3          4   CHRISTOPHER CHONG
# 4          5     PATRICK GARDNER
# ...      ...                 ...
# 36154  36155       SERENA HUGHES
# 36155  36156        JOE BROWN JR
# 36156  36157      PAULETTE ADAMS
# 36157  36158       KAUKAB MOHSIN
# 36158  36159  JOSEPHINE MCCREARY
#
#                                              JobTitle    BasePay  OvertimePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                     CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                     CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3                WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4        DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ...                                               ...        ...          ...
# ...

# %%
df[df["Year"]==2011]["Agency"]
# Out:
# 0        San Francisco
# 1        San Francisco
# 2        San Francisco
# 3        San Francisco
# 4        San Francisco
#              ...
# 36154    San Francisco
# 36155    San Francisco
# 36156    San Francisco
# 36157    San Francisco
# 36158    San Francisco
# Name: Agency, Length: 36159, dtype: object

# %%
df[df["Year"]==2011]["JobTitle"]
# Out:
# 0        GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                       CAPTAIN III (POLICE DEPARTMENT)
# 2                       CAPTAIN III (POLICE DEPARTMENT)
# 3                  WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4          DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                               ...
# 36154                SWIMMING INSTRUCTOR/POOL LIFEGUARD
# 36155                                  TRANSIT OPERATOR
# 36156        STATIONARY ENGINEER, WATER TREATMENT PLANT
# 36157                                  TRANSIT OPERATOR
# 36158                                        MANAGER IV
# Name: JobTitle, Length: 36159, dtype: object

# %%
x = df[df["Year"]==2011]
x[x["BasePay"]>=150000]
# Out:
#         Id       EmployeeName                                        JobTitle  \
# 0        1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1        2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2        3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 7        8      DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8        9     MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# ...    ...                ...                                             ...
# 2138  2139       ADRIENNE PON                                      MANAGER VI
# 2140  2141    DENISE MARTINEZ                                      MANAGER VI
# 2168  2169     SHARON REARDON                       ATTORNEY (CIVIL/CRIMINAL)
# 2169  2170  LAWRENCE DE SOUZA                       ATTORNEY (CIVIL/CRIMINAL)
# 2188  2189        PAULA KEHOE                                      MANAGER IV
#
# ...

# %%
df["TotalPayBenefits"].max()
# Out:
# 567595.43

# %%
df[df["TotalPayBenefits"]==567595.43]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
b = []
for i in range(2011 , 2015):
            e = df[df["Year"]==i]["BasePay"].max()
            b.append(e)
b
# Out:
# [294580.02, 302578.0, 319275.01, 318835.49]

# %%
d = []
for i in range(2011 , 2015):
            e = df[df["Year"]==i]["BasePay"].mean()
            d.append(e)
d
# Out:
# [63595.95651677314, 65436.40685742263, 69630.03021648065, 66564.42192449959]

# %%
r = []
for i in range(2011 , 2015):
            e = df[df["Year"]==i]["BasePay"].min()
            r.append(e)
r
# Out:
# [0.0, -166.01, 15.83, 0.0]

# %%
c = [2011 , 2012 , 2013 , 2014]
import matplotlib.pyplot as plt 
plt.plot(c , b)
plt.plot(c , d)
plt.plot(c , r)
plt.show()

# %%
plt.subplot(3 , 1 , 1)
plt.plot(c , b)

plt.subplot(3 , 1 , 2)
plt.plot(c , d)

plt.subplot(3 , 1 , 3)
plt.plot(c , r)
plt.show()
